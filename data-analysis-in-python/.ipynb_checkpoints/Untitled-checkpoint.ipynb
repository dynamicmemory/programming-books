# %%
import numpy as np
import pandas as pd

# %%
from datetime import datetime 
from datetime import timedelta

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2026, 2, 23, 16, 26, 37, 73737)

# %%
now.year, now.month, now.day
# Out:
# (2026, 2, 23)

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8,15)

# %%
delta
# Out:
# datetime.timedelta(days=926, seconds=56700)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
start = datetime(2011, 1, 7)
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
stamp = datetime(2011, 1, 3)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime("%Y-%m-%d")
# Out:
# '2011-01-03'

# %%
datestrs = ["2011-07-06 12:00:00", "2011-08-06 00:00:00"]
idx = pd.to_datetime(datestrs + [None])

idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[us]', freq=None)

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
         datetime(2011, 1, 7), datetime(2011, 1, 8),
         datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.standard_normal(6), index=dates)

# %%
ts
# Out:
# 2011-01-02   -0.858982
# 2011-01-05   -0.924289
# 2011-01-07   -0.633596
# 2011-01-08   -1.092923
# 2011-01-10   -0.525025
# 2011-01-12   -1.092421
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[us]', freq=None)

# %%
ts.index.dtype
# Out:
# dtype('<M8[us]')

# %%
stamp = ts.index[0]

# %%
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
ts[stamp]
# Out:
# np.float64(-0.8589817204824297)

# %%
longer_ts = pd.Series(np.random.standard_normal(1000),
 index=pd.date_range("2000-01-01", periods=1000))

# %%
longer_ts
# Out:
# 2000-01-01    0.165376
# 2000-01-02    1.512929
# 2000-01-03   -0.901509
# 2000-01-04    0.595945
# 2000-01-05   -0.788663
#                 ...
# 2002-09-22   -0.815982
# 2002-09-23    0.669513
# 2002-09-24    0.994799
# 2002-09-25    0.289096
# 2002-09-26   -1.446990
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts["2001"]
# Out:
# 2001-01-01    1.142380
# 2001-01-02   -0.328066
# 2001-01-03   -0.034276
# 2001-01-04    1.127050
# 2001-01-05   -1.133583
#                 ...
# 2001-12-27   -0.280633
# 2001-12-28   -0.329390
# 2001-12-29    0.824346
# 2001-12-30   -0.538523
# 2001-12-31    0.387552
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts["2001-05": "2001-07"]
# Out:
# 2001-05-01    1.536820
# 2001-05-02   -1.122409
# 2001-05-03   -0.608015
# 2001-05-04    0.271434
# 2001-05-05   -1.282551
#                 ...
# 2001-07-27    2.309802
# 2001-07-28   -0.635321
# 2001-07-29    0.495564
# 2001-07-30   -3.299994
# 2001-07-31    0.158851
# Freq: D, Length: 92, dtype: float64

# %%
dates = pd.date_range("2000-01-01", periods=100, freq="W-WED")
long_df = pd.DataFrame(np.random.standard_normal((100,4)), index=dates, columns=["Colorado", "Texas", "New York", "Ohio"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 dates = pd.date_range("2000-01-01", periods=100, freq="W-WED")
# ----> 2 long_df = pd.DataFrame(np.random.standard_normal((100,4)), index=date, columns=["Colorado", "Texas", "New York", "Ohio"])
#
# NameError: name 'date' is not defined
