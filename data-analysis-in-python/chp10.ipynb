# %%
import numpy as np 
import pandas as pd

# %%
tips = pd.read_csv("examples/tips.csv")
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
tips["tip_pct"] = tips["tip"] / tips["total_bill"]

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
grouped = tips.groupby(["day", "smoker"])
grouped_pct = grouped["tip_pct"]

grouped_pct.agg("mean")
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(["mean", "std"])
# Out:
#                  mean       std
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
grouped_pct.agg([("Average", "mean"), ("standard deviation", np.std)])
# Out:
#               Average  standard deviation
# day  smoker
# Fri  No      0.151650            0.024355
#      Yes     0.174783            0.049553
# Sat  No      0.158048            0.039323
#      Yes     0.147906            0.060640
# Sun  No      0.160113            0.041974
#      Yes     0.187250            0.150023
# Thur No      0.160298            0.038341
#      Yes     0.163863            0.038213

# %%
functions = ["count", "mean", "max"]
result = grouped[["tip_pct", "total_bill"]].agg(functions)
result["tip_pct"]
# Out:
#              count      mean       max
# day  smoker
# Fri  No          4  0.151650  0.187735
#      Yes        15  0.174783  0.263480
# Sat  No         45  0.158048  0.291990
#      Yes        42  0.147906  0.325733
# Sun  No         57  0.160113  0.252672
#      Yes        19  0.187250  0.710345
# Thur No         45  0.160298  0.266312
#      Yes        17  0.163863  0.241255

# %%
def top(df, n=5, column="tip_pct"):
    return df.sort_values(column, ascending=False)[:n]

# %%
top(tips, n=6)
# Out:
#      total_bill   tip smoker  day    time  size   tip_pct
# 172        7.25  5.15    Yes  Sun  Dinner     2  0.710345
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.416667
# 67         3.07  1.00    Yes  Sat  Dinner     1  0.325733
# 232       11.61  3.39     No  Sat  Dinner     2  0.291990
# 183       23.17  6.50    Yes  Sun  Dinner     4  0.280535
# 109       14.31  4.00    Yes  Sat  Dinner     2  0.279525

# %%
tips.groupby("smoker").apply(top)
# Out:
#             total_bill   tip   day    time  size   tip_pct
# smoker
# No     232       11.61  3.39   Sat  Dinner     2  0.291990
#        149        7.51  2.00  Thur   Lunch     2  0.266312
#        51        10.29  2.60   Sun  Dinner     2  0.252672
#        185       20.69  5.00   Sun  Dinner     5  0.241663
#        88        24.71  5.85  Thur   Lunch     2  0.236746
# Yes    172        7.25  5.15   Sun  Dinner     2  0.710345
#        178        9.60  4.00   Sun  Dinner     2  0.416667
#        67         3.07  1.00   Sat  Dinner     1  0.325733
#        183       23.17  6.50   Sun  Dinner     4  0.280535
#        109       14.31  4.00   Sat  Dinner     2  0.279525

# %%
tips.groupby(["smoker", "day"]).apply(top, n=1, column="total_bill")
# Out:
#                  total_bill    tip    time  size   tip_pct
# smoker day
# No     Fri  94        22.75   3.25  Dinner     2  0.142857
#        Sat  212       48.33   9.00  Dinner     4  0.186220
#        Sun  156       48.17   5.00  Dinner     6  0.103799
#        Thur 142       41.19   5.00   Lunch     5  0.121389
# Yes    Fri  95        40.17   4.73  Dinner     4  0.117750
#        Sat  170       50.81  10.00  Dinner     3  0.196812
#        Sun  182       45.35   3.50  Dinner     3  0.077178
#        Thur 197       43.11   5.00   Lunch     4  0.115982

# %%
frame = pd.DataFrame({"data1": np.random.standard_normal(1000), "data2": np.random.standard_normal(1000)})

# %%
frame.head()
# Out:
#       data1     data2
# 0  0.735512 -0.265216
# 1 -0.565933 -2.146414
# 2 -0.071156 -0.181267
# 3 -0.514501  1.227300
# 4 -0.022704 -1.147184

# %%
quartiles = pd.cut(frame["data1"], 4)
quartiles.head()
# Out:
# 0    (0.0328, 1.675]
# 1    (-1.61, 0.0328]
# 2    (-1.61, 0.0328]
# 3    (-1.61, 0.0328]
# 4    (-1.61, 0.0328]
# Name: data1, dtype: category
# Categories (4, interval[float64, right]): [(-3.259, -1.61] < (-1.61, 0.0328] < (0.0328, 1.675] < (1.675, 3.318]]

# %%
def get_stats(group):
    return pd.DataFrame({"min": group.min(),"max": group.max(),"count": group.count(), "mean": group.mean()})

# %%
grouped = frame.groupby(quartiles)

# %%
grouped

# %%
s= pd.Series(np.random.standard_normal(6))
s[::2] = np.nan
s
# Out:
# 0         NaN
# 1    0.494555
# 2         NaN
# 3    0.050507
# 4         NaN
# 5   -0.248968
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0    0.098698
# 1    0.494555
# 2    0.098698
# 3    0.050507
# 4    0.098698
# 5   -0.248968
# dtype: float64

# %%
states = ["Ohio", "New York", "Vermont", "Florida", "Oregon", "Nevada", "California", "Idaho"]
group_key = ["East", "East", "East", "East", "West", "West", "West", "West"]

data = pd.Series(np.random.standard_normal(8), index=states)
data
# Out:
# Ohio         -2.310530
# New York      0.086934
# Vermont       0.755867
# Florida       0.861930
# Oregon       -0.261292
# Nevada        0.687739
# California    0.540000
# Idaho        -1.874224
# dtype: float64

# %%
data[["Vermont", "Nevada", "Idaho"]] = np.nan

# %%
data
# Out:
# Ohio         -2.310530
# New York      0.086934
# Vermont            NaN
# Florida       0.861930
# Oregon       -0.261292
# Nevada             NaN
# California    0.540000
# Idaho              NaN
# dtype: float64

# %%
data.groupby(group_key).size()
# Out:
# East    4
# West    4
# dtype: int64

# %%
data.groupby(group_key).count()
data.groupby(group_key).mean()
# Out:
# East   -0.453889
# West    0.139354
# dtype: float64

# %%
def fill_mean(group):
    return group.fillna(group.mean())

# %%
data.groupby(group_key).apply(fill_mean)
# Out:
# East  Ohio         -2.310530
#       New York      0.086934
#       Vermont      -0.453889
#       Florida       0.861930
# West  Oregon       -0.261292
#       Nevada        0.139354
#       California    0.540000
#       Idaho         0.139354
# dtype: float64

# %%
fill_values = {"East":0.5, "West": -1}

# %%
suits = ["H", "S", "C", "D"]
card_val = (list(range(1,11)) + [10] *3) *4

base_names = ["A"] + list(range(2, 11)) + ["J", "K", "Q"]
cards = []
for suit in suits:
    cards.extend(str(num) + suit for num in base_names)
deck = pd.Series(card_val, index=cards)

# %%
deck.head(13)
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def get_suit(card):
    return card[-1]
def draw(deck, n=5):
    return deck.sample(n)

# %%
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# C  AC     1
#    4C     4
# D  AD     1
#    2D     2
# H  3H     3
#    6H     6
# S  7S     7
#    QS    10
# dtype: int64

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)
# Out:
# JC    10
# 2C     2
# 4D     4
# 7D     7
# 9H     9
# AH     1
# QS    10
# 5S     5
# dtype: int64

# %%
means = data.groupby(group_key).mean()

# %%
df = pd.DataFrame({"category": ["a", "a", "a", "a",
 "b", "b", "b", "b"],
 "data": np.random.standard_normal(8),
 "weights": np.random.uniform(size=8)})

# %%
df
# Out:
#   category      data   weights
# 0        a  2.141104  0.982435
# 1        a  0.766441  0.062869
# 2        a  1.047906  0.398513
# 3        a  0.309773  0.884165
# 4        b  1.324756  0.452080
# 5        b -1.428269  0.476008
# 6        b -0.633219  0.391422
# 7        b -0.476924  0.922938

# %%
grouped = df.groupby("category")

# %%
def get_wavg(group):
    return np.average(group["data"], weights=group["weights"])

# %%
grouped.apply(get_wavg)
# Out:
# category
# a    1.221305
# b   -0.342928
# dtype: float64

# %%
close_px = pd.read_csv("examples/stock_px.csv", parse_dates=True,index_col=0)

# %%
close_px.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %%
def spx_corr(group):
    return group.corrwith(group["SPX"])

# %%
rets = close_px.pct_change().dropna()

# %%
def get_year(x):
    return x.year

# %%
by_year = rets.groupby(get_year)

# %%
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
import statsmodels.api as sm 

def regress(data, yvar=None, xvars=None):
    Y=data[yvars]
    X=data[xvars]
    X["intercept"] = 1.
    result = sm.OLS(Y, X).fit()
    return result.params

# %%
by_year.apply(regress, yvar="APPL", xvars=["SPX"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 by_year.apply(regress, yvar="APPL", xvars=["SPX"])
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1650, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1647 else:
#    1648     f = func
# -> 1650 return self._python_apply_general(f, self._obj_with_exclusions)
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1687, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1652 @final
#    1653 def _python_apply_general(
#    1654     self,
#    (...)   1659     is_agg: bool = False,
#    1660 ) -> NDFrameT:
#    1661     """
#    1662     Apply function f in python space
#    1663
#    (...)   1685         data after applying f
#    1686     """
# -> 1687     values, mutated = self._grouper.apply_groupwise(f, data)
#    1688     if not_indexed_same is None:
#    1689         not_indexed_same = mutated
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:1029, in BaseGrouper.apply_groupwise(self, f, data)
#    1027 # group might be modified
#    1028 group_axes = group.axes
# -> 1029 res = f(group)
#    1030 if not mutated and not _is_indexed_like(res, group_axes):
#    1031     mutated = True
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1641, in GroupBy.apply.<locals>.f(g)
#    1639 @wraps(func)
#    1640 def f(g):
# -> 1641     return func(g, *args, **kwargs)
#
# Cell In[83], line 4, in regress(data, yvar, xvars)
#       3 def regress(data, yvar=None, xvars=None):
# ----> 4     Y=data[yvars]
#       5     X=data[xvars]
#       6     X["intercept"] = 1.
#
# NameError: name 'yvars' is not defined

# %%
df = pd.DataFrame({'key': ['a', 'b', 'c'] * 4, 'value': np.arange(12.)})

# %%
df
# Out:
#    key  value
# 0    a    0.0
# 1    b    1.0
# 2    c    2.0
# 3    a    3.0
# 4    b    4.0
# 5    c    5.0
# 6    a    6.0
# 7    b    7.0
# 8    c    8.0
# 9    a    9.0
# 10   b   10.0
# 11   c   11.0

# %%
g = df.groupby("key")
g.mean()
# Out:
#      value
# key
# a      4.5
# b      5.5
# c      6.5

# %%
g["value"]

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
tips.pivot_table(index="day")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 tips.pivot_table(index="day")
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/frame.py:11143, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11125 @Substitution("")
#   11126 @Appender(_shared_docs["pivot_table"])
#   11127 def pivot_table(
#    (...)  11139     **kwargs,
#   11140 ) -> DataFrame:
#   11141     from pandas.core.reshape.pivot import pivot_table
# > 11143     return pivot_table(
#   11144         self,
#   11145         values=values,
#   11146         index=index,
#   11147         columns=columns,
#   11148         aggfunc=aggfunc,
#   11149         fill_value=fill_value,
#   11150         margins=margins,
#   11151         dropna=dropna,
#   11152         margins_name=margins_name,
#   11153         observed=observed,
#   11154         sort=sort,
#   11155         **kwargs,
#   11156     )
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/reshape/pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
#     265     return table.__finalize__(data, method="pivot_table")
# --> 267 table = __internal_pivot_table(
#     268     data,
#     269     values,
#     270     index,
#     271     columns,
#     272     aggfunc,
#     273     fill_value,
#     274     margins,
#     275     dropna,
#     276     margins_name,
#     277     observed,
#     278     sort,
#     279     kwargs,
#     280 )
#     281 return table.__finalize__(data, method="pivot_table")
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/reshape/pivot.py:344, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, kwargs)
#     339 if values_passed:
#     340     # GH#57876 and GH#61292
#     341     # mypy is not aware `grouped[values]` will always be a DataFrameGroupBy
#     342     grouped = grouped[values]  # type: ignore[assignment]
# --> 344 agged = grouped.agg(aggfunc, **kwargs)
#     346 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     347     agged = agged.dropna(how="all")
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/apply.py:291, in Apply.agg(self)
#     288 func = self.func
#     290 if isinstance(func, str):
# --> 291     return self.apply_str()
#     293 if is_dict_like(func):
#     294     return self.agg_dict_like()
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/apply.py:701, in Apply.apply_str(self)
#     697     if "axis" in arg_names and not isinstance(
#     698         obj, (SeriesGroupBy, DataFrameGroupBy)
#     699     ):
#     700         self.kwargs["axis"] = self.axis
# --> 701 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/apply.py:792, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     790 f = getattr(obj, func)
#     791 if callable(f):
# --> 792     return f(*args, **kwargs)
#     794 # people may aggregate on a non-callable attribute
#     795 # but don't let them think they can pass args to it
#     796 assert len(args) == 0
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/internals/managers.py:1629, in BlockManager.grouped_reduce(self, func)
#    1627             result_blocks = extend_blocks(applied, result_blocks)
#    1628     else:
# -> 1629         applied = blk.apply(func)
#    1630         result_blocks = extend_blocks(applied, result_blocks)
#    1632 if len(result_blocks) == 0:
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:957, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     953 assert kind in ["transform", "aggregate"]
#     955 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 957 return cy_op.cython_operation(
#     958     values=values,
#     959     axis=axis,
#     960     min_count=min_count,
#     961     comp_ids=self.ids,
#     962     ngroups=self.ngroups,
#     963     **kwargs,
#     964 )
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~/projects/programming-books/data-analysis-in-python/.venv/lib/python3.14/site-packages/pandas/core/arrays/arrow/array.py:2634, in ArrowExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2622 if isinstance(self.dtype, StringDtype):
#    2623     if how in [
#    2624         "prod",
#    2625         "mean",
#    (...)   2632         "skew",
#    2633     ]:
# -> 2634         raise TypeError(
#    2635             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2636         )
#    2637     return super()._groupby_op(
#    2638         how=how,
#    2639         has_dropped_na=has_dropped_na,
#    (...)   2643         **kwargs,
#    2644     )
#    2646 # maybe convert to a compatible dtype optimized for groupby
#
# TypeError: dtype 'str' does not support operation 'mean'
